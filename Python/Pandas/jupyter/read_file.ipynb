# %%
import pandas as pd

# %%
df=pd.read_json("095 supermarkets.json")
df =df.set_index("ID")

# %%
df
# Out:
#             Address           City Country  Employees         Name  \
# ID
# 1      3666 21st St  San Francisco     USA          8      Madeira
# 2    735 Dolores St  San Francisco     USA         15  Bready Shop
# 3       332 Hill St  San Francisco     USA         25  Super River
# 4      3995 23rd St  San Francisco     USA         10   Ben's Shop
# 5   1056 Sanchez St  San Francisco     USA         12      Sanchez
# 6   551 Alvarado St  San Francisco     USA         20   Richvalley
#
#                State
# ID
# 1           CA 94114
# 2           CA 94119
# 3   California 94114
# 4           CA 94114
# 5         California
# 6           CA 94114

# %%
df.loc[:,["City","Name"]]
# Out:
#              City         Name
# ID
# 1   San Francisco      Madeira
# 2   San Francisco  Bready Shop
# 3   San Francisco  Super River
# 4   San Francisco   Ben's Shop
# 5   San Francisco      Sanchez
# 6   San Francisco   Richvalley

# %%
df.iloc[1:5,2:3]
# Out:
#    Country
# ID
# 2      USA
# 3      USA
# 4      USA
# 5      USA

# %%
df
# Out:
#             Address           City Country  Employees         Name  \
# ID
# 1      3666 21st St  San Francisco     USA          8      Madeira
# 2    735 Dolores St  San Francisco     USA         15  Bready Shop
# 3       332 Hill St  San Francisco     USA         25  Super River
# 4      3995 23rd St  San Francisco     USA         10   Ben's Shop
# 5   1056 Sanchez St  San Francisco     USA         12      Sanchez
# 6   551 Alvarado St  San Francisco     USA         20   Richvalley
#
#                State
# ID
# 1           CA 94114
# 2           CA 94119
# 3   California 94114
# 4           CA 94114
# 5         California
# 6           CA 94114

# %%
df.drop("Address",1)
# Out:
#              City Country  Employees         Name             State
# ID
# 1   San Francisco     USA          8      Madeira          CA 94114
# 2   San Francisco     USA         15  Bready Shop          CA 94119
# 3   San Francisco     USA         25  Super River  California 94114
# 4   San Francisco     USA         10   Ben's Shop          CA 94114
# 5   San Francisco     USA         12      Sanchez        California
# 6   San Francisco     USA         20   Richvalley          CA 94114

# %%
df["Continent"] = df.shape[0]*["America"]

# %%
df
# Out:
#             Address           City Country  Employees         Name  \
# ID
# 1      3666 21st St  San Francisco     USA          8      Madeira
# 2    735 Dolores St  San Francisco     USA         15  Bready Shop
# 3       332 Hill St  San Francisco     USA         25  Super River
# 4      3995 23rd St  San Francisco     USA         10   Ben's Shop
# 5   1056 Sanchez St  San Francisco     USA         12      Sanchez
# 6   551 Alvarado St  San Francisco     USA         20   Richvalley
#
#                State Continent
# ID
# 1           CA 94114   America
# 2           CA 94119   America
# 3   California 94114   America
# 4           CA 94114   America
# 5         California   America
# 6           CA 94114   America

# %%
df.T
# Out:
# ID                     1               2                 3              4  \
# Address     3666 21st St  735 Dolores St       332 Hill St   3995 23rd St
# City       San Francisco   San Francisco     San Francisco  San Francisco
# Country              USA             USA               USA            USA
# Employees              8              15                25             10
# Name             Madeira     Bready Shop       Super River     Ben's Shop
# State           CA 94114        CA 94119  California 94114       CA 94114
# Continent        America         America           America        America
#
# ID                       5                6
# Address    1056 Sanchez St  551 Alvarado St
# City         San Francisco    San Francisco
# Country                USA              USA
# Employees               12               20
# Name               Sanchez       Richvalley
# State           California         CA 94114
# Continent          America          America
